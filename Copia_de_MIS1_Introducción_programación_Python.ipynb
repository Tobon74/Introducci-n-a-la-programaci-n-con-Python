# %% [markdown]
# <a href="https://colab.research.google.com/github/Tobon74/Introducci-n-a-la-programaci-n-con-Python/blob/main/Copia_de_MIS1_Introducci%C3%B3n_programaci%C3%B3n_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción a la programación con Python

# %% [markdown]
# ### Tipo de Datos
#
# * Simple:

# %% [markdown]
# #### Número Entero (int)
# Este tipo de dato se corresponde con números enteros, es decir, sin parte decimal.

# %%
# 1. Pon valores de sin decimal, por ejemplo: 99, 59 ,1 ,10
entero = 10
print("El resultado de la variable es:",entero,"de tipo",type(entero))
# Out:
# El resultado de la variable es: 10 de tipo <class 'int'>

# %% [markdown]
# #### Número Decimal (float)
#
# Este tipo de dato se corresponde con números reales con parte decimal. Cabe destacar que el separador decimal en Python es el punto (.) y no la coma (,).

# %%
# 1. Pon valores de sin decimal, por ejemplo: 1.0, 3.879 , 78.0001 ,10.9999
decimal = 1.878877
print("El resultado de la variable es:",decimal,"de tipo",type(decimal))
# Out:
# El resultado de la variable es: 1.878877 de tipo <class 'float'>

# %% [markdown]
# #### Booleano (bool)
#
# Este tipo de dato reconoce solamente dos valores: Verdadero (True) y Falso (False)

# %%
# 1. Pon valores de True o False
# 2. Incluye la variable Booleano en la función print
Booleano = True
print("El resultado de la variable es:",Booleano,"de tipo",type(Booleano))
# Out:
# El resultado de la variable es: True de tipo <class 'bool'>

# %% [markdown]
# #### String
#
# El tipo de dato String se utiliza para representar una cadena de caracteres (texto)

# %%
# 1. Pon en la variable String "Hola Mundo!"
# 2. Reemplazar la variable String por _
String = "Hola Mundo!"
print("El resultado de la variable es:{0} de tipo {1} ".format(String,type(String)))
# Out:
# El resultado de la variable es:Hola Mundo! de tipo <class 'str'>

# %% [markdown]
# ### Tipo de Datos
#
# * Estructurado (Colección):

# %% [markdown]
# #### Lista
# Las listas en Python son un tipo de dato que permirte contener cualquier variable sin importar que tipo de dato sea.

# %%
# 1. Utiliza la variables previamente asignadas en la lista (String, booleano, decimal, entero)
Lista = [String, Booleano, decimal, entero]
print(Lista)
# Out:
# ['Hola Mundo!', True, 1.878877, 10]

# %% [markdown]
# * Curiosidad: a la lista de una lista se le conoce como lista anidada

# %%
[[1, 2, 3], [4, 5, 7]]
# Out:
# [[1, 2, 3], [4, 5, 7]]

# %% [markdown]
# #### Diccionarios
#
# En los Diccionarios cada elemento se compone de un par clave-valor, y para su definición es necesario encerrar los elementos entre llaves.

# %%
# 1. Agrega el año de nacimiento de John F. Kennedy (1917)
# 2. Luego en modo lista junto con la muerte (1963)
diccionario = {"Nacimiento y Muerte": [1917,1963] ,"Nombre":"John F. Kennedy"}
print(diccionario)
# Out:
# {'Nacimiento y Muerte': [1917, 1963], 'Nombre': 'John F. Kennedy'}

# %% [markdown]
# #### Tuplas
#
# Las Tuplas son básicamente listas de elementos estáticos, es decir, que no pueden modificarse (decimos que las Tuplas son inmutables en Python). Para su definición, en lugar de corchetes se encierran valores separados por comas entre paréntesis.

# %%
# 1. Utiliza la variables previamente asignadas en la lista (String, booleano, decimal, entero)

Tuple  = (String, Booleano, decimal, entero)
print(Tuple)
# Out:
# ('Hola Mundo!', True, 1.878877, 10)

# %%
Lista[0] = [80]

# %%
print(Lista)
# Out:
# [[80], True, 1.878877, 10]

# %%
Tuple[0] = [80]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-45e076a1768c> in <cell line: 0>()
# ----> 1 Tuple[0] = [80]
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Ejercicio

# %% [markdown]
# ### Operadores Aritméticos

# %% [markdown]
# Realizar las siguientes operaciones y averiguar su resultado con las variables propuestas.
# a=8
# b=3
# c=-5

# %% [markdown]
# ![operadores aritmeticos.JPG](data:image/jpeg;base64,...)

# %%
2 * (a / 5 + (4 -b * 3)) % (a +  c - 2)
# Out:
# 0.20000000000000018

# %%
a - b - c * 2
# Out:
# 15

# %%
a * (c % b)
# Out:
# 8

# %%
a * (b / c)
# Out:
# -4.8

# %%
a % c
# Out:
# -2

# %%
a % b
# Out:
# 2

# %%
(a - 3 * b) % (c + 2 * - c)
# Out:
# 4

# %%
(3 * a - 2 * b) % (2 * a - c)
# Out:
# 18

# %%
(a * c) % b
# Out:
# 2

# %%
a * b / c
# Out:
# -4.8

# %%
a / c
# Out:
# -1.6

# %%
a / b
# Out:
# 2.6666666666666665

# %%
a = 8
b = 3
c = -5

# %%
a + b + c
# Out:
# 6

# %%
2 * b +3* (a-c)
# Out:
# 45
